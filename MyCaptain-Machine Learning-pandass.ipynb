# %%
import pandas as pd
import os

# %%
dataset = pd.read_csv(r"C:\Users\murtaza shabbir\Downloads\DataSetsss\Car_sales.csv")
dataset.read()

# %%
pwd
# Out:
# 'C:\\Users\\murtaza shabbir'

# %%
import pandas as pd
import os

dataset = pd.read_csv(r"C:\Users\murtaza shabbir\Downloads\DataSetsss\Car_sales.csv")
dataset.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
import pandas as pd

# %%
cars = ['BMW','Mercedeis','Suzuki','RolceRoyce','Bughatti','Honda','TVS','KIA','Jaguar']
pd.DataFrame(cars)
# Out:
#             0
# 0         BMW
# 1   Mercedeis
# 2      Suzuki
# 3  RolceRoyce
# 4    Bughatti
# 5       Honda
# 6         TVS
# 7         KIA
# 8      Jaguar

# %%
data=pd.DataFrame(index=['MH01','GJ02','RJ05','DL19'])
data
# Out:
# Empty DataFrame
# Columns: []
# Index: [MH01, GJ02, RJ05, DL19]

# %%
clr = ["Blue","Red","White","grey",'Black','Vegenta','Cloud Blue','Violet','Orange']
pd.DataFrame(clr)
# Out:
#             0
# 0        Blue
# 1         Red
# 2       White
# 3        grey
# 4       Black
# 5     Vegenta
# 6  Cloud Blue
# 7      Violet
# 8      Orange

# %%
car_data = pd.DataFrame({"Car_Company":cars,"Colour":clr,"Price":[5000000,2000000,500000,12300000,45000000,320000,87000,760000,6500000],"WheelBase":[101.2,108.1,106.9,114.6
,102.6
,108.7
,113
,107.3
,107.3
],"Fuel Capacity":[13.2,17.2,
17.2,
18,
16.4,
18.5,
23.7,
16.6,
16.6,

],"Horse Power":[140
,225
,225
,210
,150
,200
,310
,170
,193
],"Length":[172.4
,192.9
,192
,196.6
,178
,192
,198.2
,176
,176
]})



car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length
# 0   172.4
# 1   192.9
# 2   192.0
# 3   196.6
# 4   178.0
# 5   192.0
# 6   198.2
# 7   176.0
# 8   176.0

# %%
#Import dataframe
data_set = pd.read_csv(r"Cars_Sales.csv")
data_set
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
data_set.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
#Exportig DataFrame
data_set.to_csv("exported-car-sales.csv" , index=False)#False ensures that index is not export as Data

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
data_set.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales in thousands', '4-year resale value',
#        'Vehicle type', 'Price in thousands', 'Engine size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel capacity',
#        'Fuel efficiency', 'Latest Launch'],
#       dtype='object')

# %%
data_set.index
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
data_set.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# ...

# %%
data_set.mean()
# Out:
# Sales in thousands    5.299808e+01
# Horsepower            8.931543e+94
# dtype: float64

# %%
car_prices = pd.Series([3000,1500,12323])
car_prices.mean()
# Out:
# 5607.666666666667

# %%
data_set.sum()
# Out:
# Manufacturer           Acura        Acura        Acura        Acura  ...
# Model                  Integra          TL               CL          ...
# Sales in thousands                                                8320.7
# 4-year resale value    16.3619.87518.22529.72522.25523.55539.28.67536...
# Vehicle type           PassengerPassengerPassengerPassengerPassengerP...
# Price in thousands     21.528.4.4223.9933.956226.9933.438.921.97525.3...
# Engine size            1.83.23.23.51.82.84.22.52.82.83.13.83.83.84.64...
# Horsepower             1402252252101502003101701931931752402052052752...
# Wheelbase              101.2108.1106.9114.6102.6108.7113107.3107.3111...
# Width                  67.370.370.671.468.276.17468.468.570.972.772.7...
# Length                 172.4192.9192196.6178192198.2176176188194.6196...
# Curb weight            2.6393.5173.473.852.9983.5613.9023.1793.1973.4...
# Fuel capacity          13.217.217.21816.418.523.716.616.618.517.517.5...
# ...

# %%
data_set["Sales in thousands"].sum()
# Out:
# 8320.698

# %%
len(data_set)
# Out:
# 157

# %%
########VIEWING & SELECTING Data##########################

# %%
data_set.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
data_set.head(6)
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
# 5  Audi           A6                             18.780              23.555
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# ...

# %%
data_set.tail()
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#     Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 152    Passenger               24.4         1.9        160     100.5  67.6
# 153    Passenger               27.5         2.4        168     104.9  69.3
# 154    Passenger               28.8         2.4        168     104.9  69.3
# 155    Passenger               45.5         2.3        236     104.9  71.5
# 156    Passenger                 36         2.9        201     109.9  72.1
#
# ...

# %%
animals = pd.Series(['cat','dog','lion','deer','cheetah'],index=[1,4,8,12,16])

# %%
animals
# Out:
# 1         cat
# 4         dog
# 8        lion
# 12       deer
# 16    cheetah
# dtype: object

# %%
animals.loc[12]
# Out:
# 'deer'

# %%
data_set.loc[30]
# Out:
# Manufacturer               Chrysler
# Model                  Concorde
# Sales in thousands                31.148
# 4-year resale value               13.725
# Vehicle type                   Passenger
# Price in thousands                22.245
# Engine size                          2.7
# Horsepower                           200
# Wheelbase                            113
# Width                               74.4
# Length                             209.1
# Curb weight                        3.452
# Fuel capacity                         17
# Fuel efficiency                       26
# Latest Launch                   6-Jun-14
# Name: 30, dtype: object

# %%
animals.iloc[:1]
# Out:
# 1    cat
# dtype: object

# %%
data_set
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
data_set.loc[:5]
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
# 5  Audi           A6                             18.780              23.555
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# ...

# %%
data_set["Manufacturer"]
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4      Audi
#            ...
# 152    Volvo
# 153    Volvo
# 154    Volvo
# 155    Volvo
# 156    Volvo
# Name: Manufacturer, Length: 157, dtype: object

# %%
data_set.Manufacturer
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4      Audi
#            ...
# 152    Volvo
# 153    Volvo
# 154    Volvo
# 155    Volvo
# 156    Volvo
# Name: Manufacturer, Length: 157, dtype: object

# %%
data_set[data_set["Model"]=="TL"]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
data_set[data_set["Width"] > 67.9]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-e2d622ca8afe> in <module>
# ----> 1 data_set[data_set["Width"] >= 67.9]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     524         rvalues = extract_array(other, extract_numpy=True)
#     525
# --> 526         res_values = comparison_op(lvalues, rvalues, op)
#     527
#     528         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# ...

# %%
car_data
# Out:
#   Car_Company Colour     Price
# 0         BMW   Blue   5000000
# 1   Mercedeis    Red   2000000
# 2      Suzuki  White    500000
# 3  RolceRoyce   grey  12300000

# %%
car_data[car_data["Car_Company"]=="Mercedeis"]
# Out:
#   Car_Company Colour    Price
# 1   Mercedeis    Red  2000000

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length
# 0   172.4
# 1   192.9
# 2   192.0
# 3   196.6
# 4   178.0
# 5   192.0
# 6   198.2
# 7   176.0
# 8   176.0

# %%
car_data = pd.DataFrame({"Car_Company":cars,"Colour":clr,"Price":[5000000,2000000,500000,12300000,45000000,320000,87000,760000,6500000],"WheelBase":[101.2,108.1,106.9,114.6
,102.6
,108.7
,113
,107.3
,107.3
],"Fuel Capacity":[13.2,17.2,
17.2,
18,
16.4,
18.5,
23.7,
16.6,
16.6,

],"Horse Power":[140
,225
,225
,210
,150
,200
,310
,170
,193
],"Length":[172.4
,192.9
,192
,196.6
,178
,192
,198.2
,176
,176
]})

car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length
# 0   172.4
# 1   192.9
# 2   192.0
# 3   196.6
# 4   178.0
# 5   192.0
# 6   198.2
# 7   176.0
# 8   176.0

# %%
pd.DataFrame(cars,index=['MH01','GJ02','RJ05','DL19','MH08','UP97','NY45','OPU9','KL008'])
# Out:
#                 0
# MH01          BMW
# GJ02    Mercedeis
# RJ05       Suzuki
# DL19   RolceRoyce
# MH08     Bughatti
# UP97        Honda
# NY45          TVS
# OPU9          KIA
# KL008      Jaguar

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length
# 0   172.4
# 1   192.9
# 2   192.0
# 3   196.6
# 4   178.0
# 5   192.0
# 6   198.2
# 7   176.0
# 8   176.0

# %%
car_data[car_data["Price"] > 3500000]
# Out:
#   Car_Company  Colour     Price  WheelBase  Fuel Capacity  Horse Power  Length
# 0         BMW    Blue   5000000      101.2           13.2          140   172.4
# 3  RolceRoyce    grey  12300000      114.6           18.0          210   196.6
# 4    Bughatti   Black  45000000      102.6           16.4          150   178.0
# 8      Jaguar  Orange   6500000      107.3           16.6          193   176.0

# %%
car_data[car_data["Colour"] == "grey"]
# Out:
#   Car_Company Colour     Price  WheelBase  Fuel Capacity  Horse Power  Length
# 3  RolceRoyce   grey  12300000      114.6           18.0          210   196.6

# %%
#pd.crosstab aggregates columns together
pd.crosstab(car_data["Car_Company"],car_data["Price"])
# Out:
# Price        87000     320000    500000    760000    2000000   5000000   \
# Car_Company
# BMW                 0         0         0         0         0         1
# Bughatti            0         0         0         0         0         0
# Honda               0         1         0         0         0         0
# Jaguar              0         0         0         0         0         0
# KIA                 0         0         0         1         0         0
# Mercedeis           0         0         0         0         1         0
# RolceRoyce          0         0         0         0         0         0
# Suzuki              0         0         1         0         0         0
# TVS                 1         0         0         0         0         0
#
# Price        6500000   12300000  45000000
# Car_Company
# BMW                 0         0         0
# Bughatti            0         0         1
# Honda               0         0         0
# Jaguar              1         0         0
# ...

# %%
#Group br data by a column and then calls operations on it
#mean in this case
car_data.groupby("Horse Power").mean()
# Out:
#                 Price  WheelBase  Fuel Capacity  Length
# Horse Power
# 140           5000000      101.2           13.2  172.40
# 150          45000000      102.6           16.4  178.00
# 170            760000      107.3           16.6  176.00
# 193           6500000      107.3           16.6  176.00
# 200            320000      108.7           18.5  192.00
# 210          12300000      114.6           18.0  196.60
# 225           1250000      107.5           17.2  192.45
# 310             87000      113.0           23.7  198.20

# %%
car_data.groupby("WheelBase").mean()
# Out:
#                 Price  Fuel Capacity  Horse Power  Length
# WheelBase
# 101.2       5000000.0           13.2        140.0   172.4
# 102.6      45000000.0           16.4        150.0   178.0
# 106.9        500000.0           17.2        225.0   192.0
# 107.3       3630000.0           16.6        181.5   176.0
# 108.1       2000000.0           17.2        225.0   192.9
# 108.7        320000.0           18.5        200.0   192.0
# 113.0         87000.0           23.7        310.0   198.2
# 114.6      12300000.0           18.0        210.0   196.6

# %%
import matplotlib.pyplot as plt
car_data["Fuel Capacity"].plot()

# %%
car_data["Horse Power"].plot()

# %%
car_data["Horse Power"].hist()

# %%
#Convert Price object to integer....kya?...chor

# %%
car_data["Car_Company"].str.lower()
# Out:
# 0           bmw
# 1     mercedeis
# 2        suzuki
# 3    rolceroyce
# 4      bughatti
# 5         honda
# 6           tvs
# 7           kia
# 8        jaguar
# Name: Car_Company, dtype: object

# %%
car_data["Car_Company"].str.upper()
# Out:
# 0           BMW
# 1     MERCEDEIS
# 2        SUZUKI
# 3    ROLCEROYCE
# 4      BUGHATTI
# 5         HONDA
# 6           TVS
# 7           KIA
# 8        JAGUAR
# Name: Car_Company, dtype: object

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length
# 0   172.4
# 1   192.9
# 2   192.0
# 3   196.6
# 4   178.0
# 5   192.0
# 6   198.2
# 7   176.0
# 8   176.0

# %%
car_data["Horse Power"].fillna(car_data["Horse Power"].mean(),inplace=True)

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2         140
# 1   Mercedeis         Red   2000000      108.1           17.2         225
# 2      Suzuki       White    500000      106.9           17.2         225
# 3  RolceRoyce        grey  12300000      114.6           18.0         NaN
# 4    Bughatti       Black  45000000      102.6           16.4         150
# 5       Honda     Vegenta    320000      108.7           18.5         200
# 6         TVS  Cloud Blue     87000      113.0           23.7         310
# 7         KIA      Violet    760000      107.3           16.6         NaN
# 8      Jaguar      Orange   6500000      107.3           16.6         193
#
#    Length
# 0   172.4
# 1   192.9
# 2   192.0
# 3   196.6
# 4   178.0
# 5   192.0
# 6   198.2
# 7   176.0
# 8   176.0

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length
# 0   172.4
# 1   192.9
# 2   192.0
# 3   196.6
# 4   178.0
# 5   192.0
# 6   198.2
# 7   176.0
# 8   176.0

# %%
car_data=car_data.dropna()
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length
# 0   172.4
# 1   192.9
# 2   192.0
# 3   196.6
# 4   178.0
# 5   192.0
# 6   198.2
# 7   176.0
# 8   176.0

# %%
car_sales_missing_dropped = car_data.dropna()
car_sales_missing_dropped
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length
# 0   172.4
# 1   192.9
# 2   192.0
# 3   196.6
# 4   178.0
# 5   192.0
# 6   198.2
# 7   176.0
# 8   176.0

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
#Column from series
seats_clmn = pd.Series([7,90,23,2,5])
#New column called Seats
car_data["Seats"] = seats_clmn

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length  Seats
# 0   172.4    7.0
# 1   192.9   90.0
# 2   192.0   23.0
# 3   196.6    2.0
# 4   178.0    5.0
# 5   192.0    NaN
# 6   198.2    NaN
# 7   176.0    NaN
# 8   176.0    NaN

# %%
car_data["Seats"].fillna(car_data["Seats"].mean(),inplace=True)

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length  Seats
# 0   172.4    7.0
# 1   192.9   90.0
# 2   192.0   23.0
# 3   196.6    2.0
# 4   178.0    5.0
# 5   192.0   25.4
# 6   198.2   25.4
# 7   176.0   25.4
# 8   176.0   25.4

# %%
odometer = pd.Series([150043,87899,32549,11179,213095,99213,45698,54738,60000])
car_data["Odometer(Km)"] = odometer

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length  Seats  Odometer(Km)
# 0   172.4    7.0        150043
# 1   192.9   90.0         87899
# 2   192.0   23.0         32549
# 3   196.6    2.0         11179
# 4   178.0    5.0        213095
# ...

# %%
fuel_economy = pd.Series([9.3,7.5,5.0,9.6,8.7,4.7,7.6,8.7,3.0])
car_data["Fuel Economy /100km"] = fuel_economy

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length  Seats  Odometer(Km)  Fuel Economy /100km
# 0   172.4    7.0        150043                  9.3
# 1   192.9   90.0         87899                  7.5
# 2   192.0   23.0         32549                  5.0
# ...

# %%
#Fuel Use = Odometer reading * Mileage
car_data["Total Fuel Use"] = car_data["Odometer(Km)"] * car_data["Fuel Economy /100km"]

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length  Seats  Odometer(Km)  Fuel Economy /100km  Total Fuel Use
# 0   172.4    7.0        150043                  9.3       1395399.9
# 1   192.9   90.0         87899                  7.5        659242.5
# ...

# %%
#Create a column for a single value
car_data["No.of Wheels"] = 4

# %%
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length  Seats  Odometer(Km)  Fuel Economy /100km  Total Fuel Use  \
# 0   172.4    7.0        150043                  9.3       1395399.9
# 1   192.9   90.0         87899                  7.5        659242.5
# ...

# %%
#New column with a 'bool' datatype
car_data["Passed Road Safety"] = True
car_data
# Out:
#   Car_Company      Colour     Price  WheelBase  Fuel Capacity  Horse Power  \
# 0         BMW        Blue   5000000      101.2           13.2          140
# 1   Mercedeis         Red   2000000      108.1           17.2          225
# 2      Suzuki       White    500000      106.9           17.2          225
# 3  RolceRoyce        grey  12300000      114.6           18.0          210
# 4    Bughatti       Black  45000000      102.6           16.4          150
# 5       Honda     Vegenta    320000      108.7           18.5          200
# 6         TVS  Cloud Blue     87000      113.0           23.7          310
# 7         KIA      Violet    760000      107.3           16.6          170
# 8      Jaguar      Orange   6500000      107.3           16.6          193
#
#    Length  Seats  Odometer(Km)  Fuel Economy /100km  Total Fuel Use  \
# 0   172.4    7.0        150043                  9.3       1395399.9
# 1   192.9   90.0         87899                  7.5        659242.5
# ...

# %%
#Removing/Dropping a column
car_data = car_data.drop("WheelBase", axis=1)

# %%
car_data
# Out:
#   Car_Company      Colour     Price  Fuel Capacity  Horse Power  Length  \
# 0         BMW        Blue   5000000           13.2          140   172.4
# 1   Mercedeis         Red   2000000           17.2          225   192.9
# 2      Suzuki       White    500000           17.2          225   192.0
# 3  RolceRoyce        grey  12300000           18.0          210   196.6
# 4    Bughatti       Black  45000000           16.4          150   178.0
# 5       Honda     Vegenta    320000           18.5          200   192.0
# 6         TVS  Cloud Blue     87000           23.7          310   198.2
# 7         KIA      Violet    760000           16.6          170   176.0
# 8      Jaguar      Orange   6500000           16.6          193   176.0
#
#    Seats  Odometer(Km)  Fuel Economy /100km  Total Fuel Use  No.of Wheels  \
# 0    7.0        150043                  9.3       1395399.9             4
# 1   90.0         87899                  7.5        659242.5             4
# ...

# %%
#Randomizing data in the data in the dataFrame

car_data_shuffled = car_data.sample(frac=1)

# %%
car_data_shuffled
# Out:
#   Car_Company      Colour     Price  Fuel Capacity  Horse Power  Length  \
# 6         TVS  Cloud Blue     87000           23.7          310   198.2
# 7         KIA      Violet    760000           16.6          170   176.0
# 4    Bughatti       Black  45000000           16.4          150   178.0
# 8      Jaguar      Orange   6500000           16.6          193   176.0
# 5       Honda     Vegenta    320000           18.5          200   192.0
# 3  RolceRoyce        grey  12300000           18.0          210   196.6
# 1   Mercedeis         Red   2000000           17.2          225   192.9
# 0         BMW        Blue   5000000           13.2          140   172.4
# 2      Suzuki       White    500000           17.2          225   192.0
#
#    Seats  Odometer(Km)  Fuel Economy /100km  Total Fuel Use  No.of Wheels  \
# 6   25.4         45698                  7.6        347304.8             4
# 7   25.4         54738                  8.7        476220.6             4
# ...

# %%
#Sample 20% of the data
car_data_shuffled.sample(frac=0.2)
# Out:
#   Car_Company      Colour     Price  Fuel Capacity  Horse Power  Length  \
# 4    Bughatti       Black  45000000           16.4          150   178.0
# 6         TVS  Cloud Blue     87000           23.7          310   198.2
#
#    Seats  Odometer(Km)  Fuel Economy /100km  Total Fuel Use  No.of Wheels  \
# 4    5.0        213095                  8.7       1853926.5             4
# 6   25.4         45698                  7.6        347304.8             4
#
#    Passed Road Safety
# 4                True
# 6                True

# %%
#reset shuffled index
car_data_shuffled.reset_index(drop = True,inplace = True)

# %%
car_data_shuffled
# Out:
#   Car_Company      Colour     Price  Fuel Capacity  Horse Power  Length  \
# 0         TVS  Cloud Blue     87000           23.7          310   198.2
# 1         KIA      Violet    760000           16.6          170   176.0
# 2    Bughatti       Black  45000000           16.4          150   178.0
# 3      Jaguar      Orange   6500000           16.6          193   176.0
# 4       Honda     Vegenta    320000           18.5          200   192.0
# 5  RolceRoyce        grey  12300000           18.0          210   196.6
# 6   Mercedeis         Red   2000000           17.2          225   192.9
# 7         BMW        Blue   5000000           13.2          140   172.4
# 8      Suzuki       White    500000           17.2          225   192.0
#
#    Seats  Odometer(Km)  Fuel Economy /100km  Total Fuel Use  No.of Wheels  \
# 0   25.4         45698                  7.6        347304.8             4
# 1   25.4         54738                  8.7        476220.6             4
# ...

# %%
car_data
# Out:
#   Car_Company      Colour     Price  Fuel Capacity  Horse Power  Length  \
# 0         BMW        Blue   5000000           13.2          140   172.4
# 1   Mercedeis         Red   2000000           17.2          225   192.9
# 2      Suzuki       White    500000           17.2          225   192.0
# 3  RolceRoyce        grey  12300000           18.0          210   196.6
# 4    Bughatti       Black  45000000           16.4          150   178.0
# 5       Honda     Vegenta    320000           18.5          200   192.0
# 6         TVS  Cloud Blue     87000           23.7          310   198.2
# 7         KIA      Violet    760000           16.6          170   176.0
# 8      Jaguar      Orange   6500000           16.6          193   176.0
#
#    Seats  Odometer(Km)  Fuel Economy /100km  Total Fuel Use  No.of Wheels  \
# 0    7.0        150043                  9.3       1395399.9             4
# 1   90.0         87899                  7.5        659242.5             4
# ...

# %%
#Lamda function:-- to change km to miles

car_data["Odometer(Km)"] = car_data["Odometer(Km)"].apply(lambda x: x/1.6)

# %%
car_data
# Out:
#   Car_Company      Colour     Price  Fuel Capacity  Horse Power  Length  \
# 0         BMW        Blue   5000000           13.2          140   172.4
# 1   Mercedeis         Red   2000000           17.2          225   192.9
# 2      Suzuki       White    500000           17.2          225   192.0
# 3  RolceRoyce        grey  12300000           18.0          210   196.6
# 4    Bughatti       Black  45000000           16.4          150   178.0
# 5       Honda     Vegenta    320000           18.5          200   192.0
# 6         TVS  Cloud Blue     87000           23.7          310   198.2
# 7         KIA      Violet    760000           16.6          170   176.0
# 8      Jaguar      Orange   6500000           16.6          193   176.0
#
#    Seats  Odometer(Km)  Fuel Economy /100km  Total Fuel Use  No.of Wheels  \
# 0    7.0     93776.875                  9.3       1395399.9             4
# 1   90.0     54936.875                  7.5        659242.5             4
# ...
